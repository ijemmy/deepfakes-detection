# %%
import glob
import cv2
import numpy as np

# %%
def show(frame, frame_no):
  cv2.imshow('Frame', frame)
  # print(frame.shape)


def write(frame, frame_no):
  frame_no_padded = str(frame_no).rjust(3, '0')
  path = f'./output_folder/{frame_no_padded}.png'
  print(f'Writing to path {path}')
  cv2.imwrite(path, frame)


def read_and_process(filename, frame_action):
  cap = cv2.VideoCapture(filename)
  frame_no = 0

  if (cap.isOpened() == False):
    print("Error opening video stream or file")

  while cap.isOpened():
    ret, frame = cap.read()
    if ret == True:
      frame_action(frame, frame_no)
      if cv2.waitKey(25) and 0xFF == ord('q'):
        break
    else:
      break
    frame_no += 1

  cap.release()
  cv2.destroyAllWindows()

# %% [markdown]
# # Displaying all videos

# %%
video_filenames = glob.glob('fake_folder/higher_quality/**/*.avi')
for filename in video_filenames:
  print("Displaying file: " + filename)
  read_and_process(filename, show)
# Out:
# Displaying file: fake_folder/higher_quality/mrjo0/sx374-video-mstk0.avi
# Displaying file: fake_folder/higher_quality/mrjo0/sx284-video-mstk0.avi
# Displaying file: fake_folder/higher_quality/mrjo0/sx194-video-mstk0.avi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-4486ec4b4d67> in <module>
#       2 for filename in video_filenames:
#       3   print("Displaying file: " + filename)
# ----> 4   read_and_process(filename, show)
#
# <ipython-input-20-0b64b0c50de0> in read_and_process(filename, frame_action)
#      22     if ret == True:
#      23       frame_action(frame, frame_no)
# ---> 24       if cv2.waitKey(25) and 0xFF == ord('q'):
#      25         break
#      26     else:
#
# KeyboardInterrupt:

# %%
file_to_write = 'fake_folder/higher_quality/fadg0/sa1-video-fram1.avi'
read_and_process(file_to_write, write)
# Out:
# Writing to path ./output_folder/000.png
# Writing to path ./output_folder/001.png
# Writing to path ./output_folder/002.png
# Writing to path ./output_folder/003.png
# Writing to path ./output_folder/004.png
# Writing to path ./output_folder/005.png
# Writing to path ./output_folder/006.png
# Writing to path ./output_folder/007.png
# Writing to path ./output_folder/008.png
# Writing to path ./output_folder/009.png
# Writing to path ./output_folder/010.png
# Writing to path ./output_folder/011.png
# Writing to path ./output_folder/012.png
# Writing to path ./output_folder/013.png
# Writing to path ./output_folder/014.png
# Writing to path ./output_folder/015.png
# Writing to path ./output_folder/016.png
# Writing to path ./output_folder/017.png
# Writing to path ./output_folder/018.png
# Writing to path ./output_folder/019.png
# Writing to path ./output_folder/020.png
# Writing to path ./output_folder/021.png
# Writing to path ./output_folder/022.png
# Writing to path ./output_folder/023.png
# Writing to path ./output_folder/024.png
# Writing to path ./output_folder/025.png
# Writing to path ./output_folder/026.png
# Writing to path ./output_folder/027.png
# Writing to path ./output_folder/028.png
# Writing to path ./output_folder/029.png
# Writing to path ./output_folder/030.png
# Writing to path ./output_folder/031.png
# Writing to path ./output_folder/032.png
# Writing to path ./output_folder/033.png
# Writing to path ./output_folder/034.png
# Writing to path ./output_folder/035.png
# Writing to path ./output_folder/036.png
# Writing to path ./output_folder/037.png
# Writing to path ./output_folder/038.png
# Writing to path ./output_folder/039.png
# Writing to path ./output_folder/040.png
# Writing to path ./output_folder/041.png
# Writing to path ./output_folder/042.png
# Writing to path ./output_folder/043.png
# Writing to path ./output_folder/044.png
# Writing to path ./output_folder/045.png
# Writing to path ./output_folder/046.png
# Writing to path ./output_folder/047.png
# Writing to path ./output_folder/048.png
# Writing to path ./output_folder/049.png
# Writing to path ./output_folder/050.png
# Writing to path ./output_folder/051.png
# Writing to path ./output_folder/052.png
# Writing to path ./output_folder/053.png
# Writing to path ./output_folder/054.png
# Writing to path ./output_folder/055.png
# Writing to path ./output_folder/056.png
# Writing to path ./output_folder/057.png
# Writing to path ./output_folder/058.png
# Writing to path ./output_folder/059.png
# Writing to path ./output_folder/060.png
# Writing to path ./output_folder/061.png
# Writing to path ./output_folder/062.png
# Writing to path ./output_folder/063.png
# Writing to path ./output_folder/064.png
# Writing to path ./output_folder/065.png
# Writing to path ./output_folder/066.png
# Writing to path ./output_folder/067.png
# Writing to path ./output_folder/068.png
# Writing to path ./output_folder/069.png
# Writing to path ./output_folder/070.png
# Writing to path ./output_folder/071.png
# Writing to path ./output_folder/072.png
# Writing to path ./output_folder/073.png
# Writing to path ./output_folder/074.png
# Writing to path ./output_folder/075.png
# Writing to path ./output_folder/076.png
# Writing to path ./output_folder/077.png
# Writing to path ./output_folder/078.png
# Writing to path ./output_folder/079.png
# Writing to path ./output_folder/080.png
# Writing to path ./output_folder/081.png
# Writing to path ./output_folder/082.png
# Writing to path ./output_folder/083.png
# Writing to path ./output_folder/084.png
# Writing to path ./output_folder/085.png
# Writing to path ./output_folder/086.png
# Writing to path ./output_folder/087.png
# Writing to path ./output_folder/088.png
# Writing to path ./output_folder/089.png
# Writing to path ./output_folder/090.png
# Writing to path ./output_folder/091.png
# Writing to path ./output_folder/092.png
# Writing to path ./output_folder/093.png
# Writing to path ./output_folder/094.png
# Writing to path ./output_folder/095.png
# Writing to path ./output_folder/096.png
# Writing to path ./output_folder/097.png
# Writing to path ./output_folder/098.png
# Writing to path ./output_folder/099.png
# Writing to path ./output_folder/100.png
# Writing to path ./output_folder/101.png
# Writing to path ./output_folder/102.png
# Writing to path ./output_folder/103.png
# Writing to path ./output_folder/104.png
# Writing to path ./output_folder/105.png
# Writing to path ./output_folder/106.png
# Writing to path ./output_folder/107.png
# Writing to path ./output_folder/108.png
# Writing to path ./output_folder/109.png
# Writing to path ./output_folder/110.png
# Writing to path ./output_folder/111.png
# Writing to path ./output_folder/112.png
# Writing to path ./output_folder/113.png
# Writing to path ./output_folder/114.png
# Writing to path ./output_folder/115.png
# Writing to path ./output_folder/116.png
# Writing to path ./output_folder/117.png
# Writing to path ./output_folder/118.png
